# %%
import math
print(f'The square root of 16 is {math.sqrt(16)}')
# Out:
# The square root of 16 is 4.0

# %%
print('Hello from MCP!')
# Out:
# Hello from MCP!

# %%
x = 10
y = 20
print(f'x + y = {x + y}')
print(f'x * y = {x * y}')
# Out:
# x + y = 30
# x * y = 200
